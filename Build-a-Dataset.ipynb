# %% [markdown]
# # Building a Dataset
# Quick tutorial on building your very own dataset (and how to save it)

# %%
# Libraries
import pandas as pd

# %% [markdown]
# ## How Many?

# %%
# Number of rows or users to create
num_users = 10000

# %% [markdown]
# ## Feature Names

# %%
#  A list of 10 features
features = [
    "id",
    "gender",
    "subscriber",
    "name",
    "email",
    "last_login",
    "dob",
    "education",
    "bio",
    "rating"
]

# Creating a DF for these features
df = pd.DataFrame(columns=features)

df
# Out:
# Empty DataFrame
# Columns: [id, gender, subscriber, email, name, last_login, education, dob, bio, rating]
# Index: []

# %% [markdown]
# ## IDs

# %%
import uuid

df['id'] = [uuid.uuid4().hex for i in range(num_users)]

df
# Out:
#                                     id gender subscriber email name  \
# 0     ac8074c120f245c5b354bf55fa6045e0    NaN        NaN   NaN  NaN
# 1     8889fb15914142a7bd0cfb078c4d2283    NaN        NaN   NaN  NaN
# 2     92d5f3e001a34dc98f8a8eb605f8f02c    NaN        NaN   NaN  NaN
# 3     deb47292592e433482816ef1e117d6bd    NaN        NaN   NaN  NaN
# 4     1fa5764cb3764fb9a1f63472887f4dc5    NaN        NaN   NaN  NaN
# ...                                ...    ...        ...   ...  ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    NaN        NaN   NaN  NaN
# 9996  2073bab29db546ed83996aa1edaccce3    NaN        NaN   NaN  NaN
# 9997  815c826922c6419fb4181b6f07b41871    NaN        NaN   NaN  NaN
# 9998  282d88eaa3ff4ca1b9db684711a37bf7    NaN        NaN   NaN  NaN
# 9999  f27b8289869549e293dfa85772226b3f    NaN        NaN   NaN  NaN
#
#      last_login education  dob  bio rating
# 0           NaN       NaN  NaN  NaN    NaN
# 1           NaN       NaN  NaN  NaN    NaN
# 2           NaN       NaN  NaN  NaN    NaN
# 3           NaN       NaN  NaN  NaN    NaN
# 4           NaN       NaN  NaN  NaN    NaN
# ...         ...       ...  ...  ...    ...
# 9995        NaN       NaN  NaN  NaN    NaN
# 9996        NaN       NaN  NaN  NaN    NaN
# 9997        NaN       NaN  NaN  NaN    NaN
# 9998        NaN       NaN  NaN  NaN    NaN
# 9999        NaN       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Gender

# %%
import random

genders = ["male", "female", "non-binary"]


df['gender'] = random.choices(
    genders, 
    weights=(49,49,2), 
    k=num_users
)

df
# Out:
#                                     id  gender subscriber email name  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        NaN   NaN  NaN
# 1     8889fb15914142a7bd0cfb078c4d2283  female        NaN   NaN  NaN
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        NaN   NaN  NaN
# 3     deb47292592e433482816ef1e117d6bd    male        NaN   NaN  NaN
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        NaN   NaN  NaN
# ...                                ...     ...        ...   ...  ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male        NaN   NaN  NaN
# 9996  2073bab29db546ed83996aa1edaccce3  female        NaN   NaN  NaN
# 9997  815c826922c6419fb4181b6f07b41871  female        NaN   NaN  NaN
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        NaN   NaN  NaN
# 9999  f27b8289869549e293dfa85772226b3f    male        NaN   NaN  NaN
#
#      last_login education  dob  bio rating
# 0           NaN       NaN  NaN  NaN    NaN
# 1           NaN       NaN  NaN  NaN    NaN
# 2           NaN       NaN  NaN  NaN    NaN
# 3           NaN       NaN  NaN  NaN    NaN
# 4           NaN       NaN  NaN  NaN    NaN
# ...         ...       ...  ...  ...    ...
# 9995        NaN       NaN  NaN  NaN    NaN
# 9996        NaN       NaN  NaN  NaN    NaN
# 9997        NaN       NaN  NaN  NaN    NaN
# 9998        NaN       NaN  NaN  NaN    NaN
# 9999        NaN       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Subscriber

# %%
# Choices
choice = [True, False]

df['subscriber'] = random.choices(
    choice, 
    k=num_users
)

df
# Out:
#                                     id  gender  subscriber email name  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True   NaN  NaN
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False   NaN  NaN
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True   NaN  NaN
# 3     deb47292592e433482816ef1e117d6bd    male        True   NaN  NaN
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True   NaN  NaN
# ...                                ...     ...         ...   ...  ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False   NaN  NaN
# 9996  2073bab29db546ed83996aa1edaccce3  female       False   NaN  NaN
# 9997  815c826922c6419fb4181b6f07b41871  female        True   NaN  NaN
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True   NaN  NaN
# 9999  f27b8289869549e293dfa85772226b3f    male       False   NaN  NaN
#
#      last_login education  dob  bio rating
# 0           NaN       NaN  NaN  NaN    NaN
# 1           NaN       NaN  NaN  NaN    NaN
# 2           NaN       NaN  NaN  NaN    NaN
# 3           NaN       NaN  NaN  NaN    NaN
# 4           NaN       NaN  NaN  NaN    NaN
# ...         ...       ...  ...  ...    ...
# 9995        NaN       NaN  NaN  NaN    NaN
# 9996        NaN       NaN  NaN  NaN    NaN
# 9997        NaN       NaN  NaN  NaN    NaN
# 9998        NaN       NaN  NaN  NaN    NaN
# 9999        NaN       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Name

# %%
# Installing the needed library
# !pip install faker
# Out:
# Requirement already satisfied: faker in /Users/marcosantos/miniforge3/lib/python3.9/site-packages (8.12.1)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/marcosantos/miniforge3/lib/python3.9/site-packages (from faker) (2.8.1)
# Requirement already satisfied: text-unidecode==1.3 in /Users/marcosantos/miniforge3/lib/python3.9/site-packages (from faker) (1.3)
# Requirement already satisfied: six>=1.5 in /Users/marcosantos/miniforge3/lib/python3.9/site-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker

faker = Faker()

def name_gen(gender):
    """
    Quickly generates a name based on gender
    """
    if gender=='male':
        return faker.name_male()
    elif gender=='female':
        return faker.name_female()
    
    return faker.name()

df['name'] = [name_gen(i) for i in df['gender']]

df
# Out:
#                                     id  gender  subscriber email  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True   NaN
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False   NaN
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True   NaN
# 3     deb47292592e433482816ef1e117d6bd    male        True   NaN
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True   NaN
# ...                                ...     ...         ...   ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False   NaN
# 9996  2073bab29db546ed83996aa1edaccce3  female       False   NaN
# 9997  815c826922c6419fb4181b6f07b41871  female        True   NaN
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True   NaN
# 9999  f27b8289869549e293dfa85772226b3f    male       False   NaN
#
#                          name last_login education  dob  bio rating
# 0                  Thomas Kim        NaN       NaN  NaN  NaN    NaN
# 1               Alisha Burton        NaN       NaN  NaN  NaN    NaN
# 2            Sharon Gutierrez        NaN       NaN  NaN  NaN    NaN
# 3             Joshua Williams        NaN       NaN  NaN  NaN    NaN
# 4             Michelle Tucker        NaN       NaN  NaN  NaN    NaN
# ...                       ...        ...       ...  ...  ...    ...
# 9995  Mr. Jeremy Campbell DDS        NaN       NaN  NaN  NaN    NaN
# 9996            Shelley Allen        NaN       NaN  NaN  NaN    NaN
# 9997          Courtney Walton        NaN       NaN  NaN  NaN    NaN
# 9998        Courtney Thompson        NaN       NaN  NaN  NaN    NaN
# 9999            Jacob Rose MD        NaN       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Email

# %%
def emailGen(name, duplicateFound=False):
    """
    Generates a random email address based on the given name. 
    Adds a number at the end if a duplicate address was found.
    """
    # Fake domain name
    dom = "@fakemail.com"
    
    # Lowercasing and splitting
    name = name.lower().split(" ")
    
    # Random character to insert in the name
    chars = [".", "_"]
    
    new_name = name[0] + random.choice(chars) + name[1] 
    
    if duplicateFound:
        
        # Random number to insert at the end
        num = random.randint(0,100)
        
        # Inserting at the end
        new_name = new_name + str(num)
        
        return new_name + dom
    
    return new_name + dom
    

emails = []

for name in df['name']:
    
    # Generating the email
    email = emailGen(name)
    
    # Looping until a unique email is generated
    while email in emails:
        
        email = emailGen(name, duplicateFound=True)
    
    # Attaching the new email to the list
    emails.append(email)
    
df['email'] = emails
    
# Checking if the emails are all unique
print(df['email'].nunique()==num_users)

df
# Out:
# True
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name last_login  \
# 0            thomas_kim@fakemail.com               Thomas Kim        NaN
# 1         alisha.burton@fakemail.com            Alisha Burton        NaN
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez        NaN
# 3       joshua_williams@fakemail.com          Joshua Williams        NaN
# 4       michelle.tucker@fakemail.com          Michelle Tucker        NaN
# ...                              ...                      ...        ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS        NaN
# 9996      shelley.allen@fakemail.com            Shelley Allen        NaN
# 9997    courtney_walton@fakemail.com          Courtney Walton        NaN
# 9998  courtney_thompson@fakemail.com        Courtney Thompson        NaN
# 9999         jacob.rose@fakemail.com            Jacob Rose MD        NaN
#
#      education  dob  bio rating
# 0          NaN  NaN  NaN    NaN
# 1          NaN  NaN  NaN    NaN
# 2          NaN  NaN  NaN    NaN
# 3          NaN  NaN  NaN    NaN
# 4          NaN  NaN  NaN    NaN
# ...        ...  ...  ...    ...
# 9995       NaN  NaN  NaN    NaN
# 9996       NaN  NaN  NaN    NaN
# 9997       NaN  NaN  NaN    NaN
# 9998       NaN  NaN  NaN    NaN
# 9999       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Last Login

# %%
import datetime

def randomtimes(start, end, n):
    """
    Generates random time stamps based on a given amount between two time periods.
    """
    # The timestamp format
    frmt = "%Y-%m-%d %H:%M:%S"
    
    # Formatting the two time periods
    stime = datetime.datetime.strptime(start, frmt)
    etime = datetime.datetime.strptime(end, frmt)
    
    # Creating the pool for random times
    td = etime - stime
    
    # Generating a list with the random times
    times = [(random.random() * td + stime).strftime(frmt) for _ in range(n)]
    
    return times

# Setting the start and end times
start = "2021-08-01 00:00:00"

end = "2021-08-24 00:00:00"

df['last_login'] = randomtimes(start, end, num_users)

df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login education  dob  bio rating
# 0     2021-08-18 17:13:02       NaN  NaN  NaN    NaN
# 1     2021-08-08 16:06:47       NaN  NaN  NaN    NaN
# 2     2021-08-04 14:54:09       NaN  NaN  NaN    NaN
# 3     2021-08-08 12:27:49       NaN  NaN  NaN    NaN
# 4     2021-08-20 05:00:11       NaN  NaN  NaN    NaN
# ...                   ...       ...  ...  ...    ...
# 9995  2021-08-14 12:27:11       NaN  NaN  NaN    NaN
# 9996  2021-08-20 01:36:31       NaN  NaN  NaN    NaN
# 9997  2021-08-08 14:12:25       NaN  NaN  NaN    NaN
# 9998  2021-08-23 10:10:42       NaN  NaN  NaN    NaN
# 9999  2021-08-16 10:44:05       NaN  NaN  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Date of Birth

# %%
def random_dob(start, end, n):
    """
    Generating a list of a set number of timestamps
    """
    
    # The timestamp format
    frmt = "%Y-%m-%d"
    
    # Formatting the two time periods
    stime = datetime.datetime.strptime(start, frmt)
    etime = datetime.datetime.strptime(end, frmt)
    
    # Creating the pool for random times
    td = etime - stime
    
    # Generating a list with the random times
    times = [(random.random() * td + stime).strftime(frmt) for _ in range(n)]
    
    return times

df['dob'] = random_dob("1980-01-01", "2006-01-01", num_users)

df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login education         dob  bio rating
# 0     2021-08-18 17:13:02       NaN  1994-03-14  NaN    NaN
# 1     2021-08-08 16:06:47       NaN  1982-10-24  NaN    NaN
# 2     2021-08-04 14:54:09       NaN  2003-04-08  NaN    NaN
# 3     2021-08-08 12:27:49       NaN  1982-05-03  NaN    NaN
# 4     2021-08-20 05:00:11       NaN  2005-01-04  NaN    NaN
# ...                   ...       ...         ...  ...    ...
# 9995  2021-08-14 12:27:11       NaN  1985-03-01  NaN    NaN
# 9996  2021-08-20 01:36:31       NaN  1986-03-31  NaN    NaN
# 9997  2021-08-08 14:12:25       NaN  2000-11-25  NaN    NaN
# 9998  2021-08-23 10:10:42       NaN  1993-12-15  NaN    NaN
# 9999  2021-08-16 10:44:05       NaN  1998-12-07  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Current Education

# %%
def getEducation(dob):
    """
    Assigns an education level based on the given date of birth
    """
    # Current date
    now = datetime.datetime.now()
    
    # Date of birth
    dob = datetime.datetime.strptime(dob, "%Y-%m-%d")
    
    # Subtracting the times to get an age
    age = int((now - dob).days/365.25)
    
    # Returning education level based on age
    if age <= 18:
        return 'high school'
    elif age <= 22:
        return 'undergrad'
    elif age <= 25:
        return 'grad'
    else:
        return 'worker'

df['education'] = [getEducation(i) for i in df['dob']]

df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login    education         dob  bio rating
# 0     2021-08-18 17:13:02       worker  1994-03-14  NaN    NaN
# 1     2021-08-08 16:06:47       worker  1982-10-24  NaN    NaN
# 2     2021-08-04 14:54:09  high school  2003-04-08  NaN    NaN
# 3     2021-08-08 12:27:49       worker  1982-05-03  NaN    NaN
# 4     2021-08-20 05:00:11  high school  2005-01-04  NaN    NaN
# ...                   ...          ...         ...  ...    ...
# 9995  2021-08-14 12:27:11       worker  1985-03-01  NaN    NaN
# 9996  2021-08-20 01:36:31       worker  1986-03-31  NaN    NaN
# 9997  2021-08-08 14:12:25    undergrad  2000-11-25  NaN    NaN
# 9998  2021-08-23 10:10:42       worker  1993-12-15  NaN    NaN
# 9999  2021-08-16 10:44:05    undergrad  1998-12-07  NaN    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Bio

# %%
df['bio'] = [faker.sentence(10) for _ in range(num_users)]

df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login    education         dob  \
# 0     2021-08-18 17:13:02       worker  1994-03-14
# 1     2021-08-08 16:06:47       worker  1982-10-24
# 2     2021-08-04 14:54:09  high school  2003-04-08
# 3     2021-08-08 12:27:49       worker  1982-05-03
# 4     2021-08-20 05:00:11  high school  2005-01-04
# ...                   ...          ...         ...
# 9995  2021-08-14 12:27:11       worker  1985-03-01
# 9996  2021-08-20 01:36:31       worker  1986-03-31
# 9997  2021-08-08 14:12:25    undergrad  2000-11-25
# 9998  2021-08-23 10:10:42       worker  1993-12-15
# 9999  2021-08-16 10:44:05    undergrad  1998-12-07
#
#                                                     bio rating
# 0                Wide agent available fill poor mother.    NaN
# 1     Amount these identify main wall direction pare...    NaN
# 2     Somebody east authority turn if establish comm...    NaN
# 3       His know particularly within across few likely.    NaN
# 4     Tv available employee purpose yourself section...    NaN
# ...                                                 ...    ...
# 9995  Happy little company share life hear scientist...    NaN
# 9996             Purpose same policy series husband do.    NaN
# 9997  Which accept more civil southern think talk fi...    NaN
# 9998  Heart art size effort laugh state my tradition...    NaN
# 9999  Impact deep third join like politics blood tre...    NaN
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Rating

# %%
# The different ratings available
ratings = [1,2,3,4,5]

# Weighted ratings with a skew towards the ends
df['rating'] = random.choices(
    ratings, 
    weights=(30,10,10,10,30), 
    k=num_users
)

df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login    education         dob  \
# 0     2021-08-18 17:13:02       worker  1994-03-14
# 1     2021-08-08 16:06:47       worker  1982-10-24
# 2     2021-08-04 14:54:09  high school  2003-04-08
# 3     2021-08-08 12:27:49       worker  1982-05-03
# 4     2021-08-20 05:00:11  high school  2005-01-04
# ...                   ...          ...         ...
# 9995  2021-08-14 12:27:11       worker  1985-03-01
# 9996  2021-08-20 01:36:31       worker  1986-03-31
# 9997  2021-08-08 14:12:25    undergrad  2000-11-25
# 9998  2021-08-23 10:10:42       worker  1993-12-15
# 9999  2021-08-16 10:44:05    undergrad  1998-12-07
#
#                                                     bio  rating
# 0                Wide agent available fill poor mother.       5
# 1     Amount these identify main wall direction pare...       1
# 2     Somebody east authority turn if establish comm...       3
# 3       His know particularly within across few likely.       1
# 4     Tv available employee purpose yourself section...       1
# ...                                                 ...     ...
# 9995  Happy little company share life hear scientist...       3
# 9996             Purpose same policy series husband do.       1
# 9997  Which accept more civil southern think talk fi...       4
# 9998  Heart art size effort laugh state my tradition...       1
# 9999  Impact deep third join like politics blood tre...       5
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Saving as a CSV file

# %%
df.to_csv('dataset.csv')

# %%
# Viewing the saved csv file
csv_df = pd.read_csv('dataset.csv', index_col=0)

csv_df
# Out:
#                                     id  gender  subscriber  \
# 0     ac8074c120f245c5b354bf55fa6045e0    male        True
# 1     8889fb15914142a7bd0cfb078c4d2283  female       False
# 2     92d5f3e001a34dc98f8a8eb605f8f02c  female        True
# 3     deb47292592e433482816ef1e117d6bd    male        True
# 4     1fa5764cb3764fb9a1f63472887f4dc5  female        True
# ...                                ...     ...         ...
# 9995  c1323ab860be4d3c8870ce603ab353ea    male       False
# 9996  2073bab29db546ed83996aa1edaccce3  female       False
# 9997  815c826922c6419fb4181b6f07b41871  female        True
# 9998  282d88eaa3ff4ca1b9db684711a37bf7  female        True
# 9999  f27b8289869549e293dfa85772226b3f    male       False
#
#                                email                     name  \
# 0            thomas_kim@fakemail.com               Thomas Kim
# 1         alisha.burton@fakemail.com            Alisha Burton
# 2      sharon_gutierrez@fakemail.com         Sharon Gutierrez
# 3       joshua_williams@fakemail.com          Joshua Williams
# 4       michelle.tucker@fakemail.com          Michelle Tucker
# ...                              ...                      ...
# 9995         mr..jeremy@fakemail.com  Mr. Jeremy Campbell DDS
# 9996      shelley.allen@fakemail.com            Shelley Allen
# 9997    courtney_walton@fakemail.com          Courtney Walton
# 9998  courtney_thompson@fakemail.com        Courtney Thompson
# 9999         jacob.rose@fakemail.com            Jacob Rose MD
#
#                last_login    education         dob  \
# 0     2021-08-18 17:13:02       worker  1994-03-14
# 1     2021-08-08 16:06:47       worker  1982-10-24
# 2     2021-08-04 14:54:09  high school  2003-04-08
# 3     2021-08-08 12:27:49       worker  1982-05-03
# 4     2021-08-20 05:00:11  high school  2005-01-04
# ...                   ...          ...         ...
# 9995  2021-08-14 12:27:11       worker  1985-03-01
# 9996  2021-08-20 01:36:31       worker  1986-03-31
# 9997  2021-08-08 14:12:25    undergrad  2000-11-25
# 9998  2021-08-23 10:10:42       worker  1993-12-15
# 9999  2021-08-16 10:44:05    undergrad  1998-12-07
#
#                                                     bio  rating
# 0                Wide agent available fill poor mother.       5
# 1     Amount these identify main wall direction pare...       1
# 2     Somebody east authority turn if establish comm...       3
# 3       His know particularly within across few likely.       1
# 4     Tv available employee purpose yourself section...       1
# ...                                                 ...     ...
# 9995  Happy little company share life hear scientist...       3
# 9996             Purpose same policy series husband do.       1
# 9997  Which accept more civil southern think talk fi...       4
# 9998  Heart art size effort laugh state my tradition...       1
# 9999  Impact deep third join like politics blood tre...       5
#
# [10000 rows x 10 columns]
